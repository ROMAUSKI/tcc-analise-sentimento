# %% [markdown]
# ### 00 - Geração e Planejamento dos Dados
#
# 📝 Este notebook foi utilizado para a fase inicial de planejamento, documentação e testes dos prompts de geração de dados.
#
# A geração final dos 9 arquivos CSV brutos foi realizada manualmente através das interfaces web das respectivas IAs (Gemini, ChatGPT e Claude), com os dados sendo salvos diretamente na pasta `/data`.
#
# O processo de código-fonte do projeto (unificação, limpeza e treinamento) inicia-se no notebook **`01_training_evaluation.ipynb`**.

# %%
#Instalação
print("Instalando dependências...")
# !pip install -q pandas scikit-learn matplotlib seaborn nltk wordcloud
print("Dependências instaladas!")
# Out:
# Instalando dependências...
# Dependências instaladas!
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: C:\Python314\python.exe -m pip install --upgrade pip

# %%
#Versões Atuais das Bibliotecas Instaladas
import importlib.metadata
libs = ["pandas", "scikit-learn", "matplotlib", "seaborn", "nltk", "wordcloud"]
for lib in libs:
    try:
        version = importlib.metadata.version(lib)
        print(f"{lib}=={version}")
    except importlib.metadata.PackageNotFoundError: pass
# Out:
# 'grep' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.
